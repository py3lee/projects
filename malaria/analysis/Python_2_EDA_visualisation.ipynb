# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#What-is-malaria?" data-toc-modified-id="What-is-malaria?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>What is malaria?</a></span></li></ul></li><li><span><a href="#Primary-problem-statement" data-toc-modified-id="Primary-problem-statement-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Primary problem statement</a></span><ul class="toc-item"><li><span><a href="#Dataset" data-toc-modified-id="Dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Dataset</a></span></li><li><span><a href="#Data-dictionary" data-toc-modified-id="Data-dictionary-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data dictionary</a></span></li><li><span><a href="#Dataset-limitations" data-toc-modified-id="Dataset-limitations-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Dataset limitations</a></span></li><li><span><a href="#Assumptions-in-current-analyses" data-toc-modified-id="Assumptions-in-current-analyses-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Assumptions in current analyses</a></span></li><li><span><a href="#Limitations-of-current-analyses" data-toc-modified-id="Limitations-of-current-analyses-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Limitations of current analyses</a></span></li></ul></li><li><span><a href="#Prior-data-preprocessing-steps:" data-toc-modified-id="Prior-data-preprocessing-steps:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prior data preprocessing steps:</a></span><ul class="toc-item"><li><span><a href="#malaria_deaths.csv-->-malaria_processed_deaths.csv:-deaths" data-toc-modified-id="malaria_deaths.csv-->-malaria_processed_deaths.csv:-deaths-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><strong>malaria_deaths.csv -&gt; malaria_processed_deaths.csv: <code>deaths</code></strong></a></span></li><li><span><a href="#malaria_deaths_age.csv-->-malaria_deaths_age_processed.csv:-deaths_age" data-toc-modified-id="malaria_deaths_age.csv-->-malaria_deaths_age_processed.csv:-deaths_age-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><strong>malaria_deaths_age.csv -&gt; malaria_deaths_age_processed.csv: <code>deaths_age</code></strong></a></span></li><li><span><a href="#malaria_inc.csv-->-malaria_inc_processed.csv:-inc" data-toc-modified-id="malaria_inc.csv-->-malaria_inc_processed.csv:-inc-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><strong>malaria_inc.csv -&gt; malaria_inc_processed.csv: <code>inc</code></strong></a></span></li></ul></li><li><span><a href="#Load-libraries" data-toc-modified-id="Load-libraries-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load libraries</a></span></li><li><span><a href="#Load-preprocessed-datasets" data-toc-modified-id="Load-preprocessed-datasets-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Load preprocessed datasets</a></span><ul class="toc-item"><li><span><a href="#Checking-each-dataset-prior-to-visualization" data-toc-modified-id="Checking-each-dataset-prior-to-visualization-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Checking each dataset prior to visualization</a></span></li><li><span><a href="#malaria_deaths_processed.csv" data-toc-modified-id="malaria_deaths_processed.csv-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>malaria_deaths_processed.csv</a></span></li><li><span><a href="#malaria_deaths_processed.csv" data-toc-modified-id="malaria_deaths_processed.csv-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>malaria_deaths_processed.csv</a></span></li><li><span><a href="#malaria_inc_processed.csv" data-toc-modified-id="malaria_inc_processed.csv-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>malaria_inc_processed.csv</a></span></li></ul></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Define functions</a></span></li><li><span><a href="#Global-trends" data-toc-modified-id="Global-trends-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Global trends</a></span><ul class="toc-item"><li><span><a href="#Malaria-incidence-per-1,000-population-at-risk" data-toc-modified-id="Malaria-incidence-per-1,000-population-at-risk-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Malaria incidence per 1,000 population at risk</a></span></li><li><span><a href="#Age-standardized-malaria-death-rate-(per-100,000-people)" data-toc-modified-id="Age-standardized-malaria-death-rate-(per-100,000-people)-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Age-standardized malaria death rate (per 100,000 people)</a></span></li><li><span><a href="#Number-of-malaria-deaths-by-age-group" data-toc-modified-id="Number-of-malaria-deaths-by-age-group-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Number of malaria deaths by age group</a></span></li></ul></li><li><span><a href="#Regional-trends" data-toc-modified-id="Regional-trends-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Regional trends</a></span><ul class="toc-item"><li><span><a href="#Malaria-incidence-per-1,000-population-at-risk" data-toc-modified-id="Malaria-incidence-per-1,000-population-at-risk-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Malaria incidence per 1,000 population at risk</a></span></li><li><span><a href="#Age-standardized-malaria-death-rate-(per-100,000-people)" data-toc-modified-id="Age-standardized-malaria-death-rate-(per-100,000-people)-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Age-standardized malaria death rate (per 100,000 people)</a></span></li><li><span><a href="#Number-of-malaria-deaths-by-age-group" data-toc-modified-id="Number-of-malaria-deaths-by-age-group-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Number of malaria deaths by age group</a></span></li></ul></li><li><span><a href="#Trends-by-income/demographic-groups" data-toc-modified-id="Trends-by-income/demographic-groups-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Trends by income/demographic groups</a></span><ul class="toc-item"><li><span><a href="#Malaria-incidence-per-1,000-population-at-risk" data-toc-modified-id="Malaria-incidence-per-1,000-population-at-risk-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Malaria incidence per 1,000 population at risk</a></span></li><li><span><a href="#Age-standardized-malaria-death-rate-(per-100,000-people)" data-toc-modified-id="Age-standardized-malaria-death-rate-(per-100,000-people)-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Age-standardized malaria death rate (per 100,000 people)</a></span></li><li><span><a href="#Number-of-malaria-deaths-by-age-group" data-toc-modified-id="Number-of-malaria-deaths-by-age-group-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Number of malaria deaths by age group</a></span></li></ul></li><li><span><a href="#What-are-the-countries-with-the-high-numbers-of-malaria-deaths?" data-toc-modified-id="What-are-the-countries-with-the-high-numbers-of-malaria-deaths?-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>What are the countries with the high numbers of malaria deaths?</a></span></li><li><span><a href="#Considerations-to-improve-the-current-analyses" data-toc-modified-id="Considerations-to-improve-the-current-analyses-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Considerations to improve the current analyses</a></span></li></ul></div>

# %% [markdown]
# # Introduction
#
# ## What is malaria?
#
# [Malaria is a vector-borne parasitic tropical disease, transmitted by the bite of the female *Anopheles* mosquito](https://www.thelancet.com/journals/lancet/article/PIIS0140-6736(18)30324-6/fulltext).  Patients infected by one of the Plasmodium species can experience severe illness and death.
#
#
# # Primary problem statement
#
# Is there any observable trend on the incidence of malaria and malaria-related deaths over the years?
#
# ## Dataset
# Data Source: https://github.com/rfordatascience/tidytuesday/tree/master/data/2018/2018-11-13
#
# 3 Datasets:
#
# - malaria_inc.csv - Malaria incidence by country for all ages across the world across time
# - malaria_deaths.csv - Malaria deaths by country for all ages across the world and time.
# - malaria_deaths_age.csv - Malaria deaths by age across the world and time.
#
# note: unable to trace exact original data sources based on the data provided at https://github.com/rfordatascience/tidytuesday/tree/master/data/2018/2018-11-13.
#
# ## Data dictionary
#
# - Unable to locate.
# - It seems like the [3 datasets](https://github.com/rfordatascience/tidytuesday/tree/master/data/2018) are a compilation of variuous aggregate data sources from [Our World in Data](https://ourworldindata.org/malaria#data-sources), which, in turn, used data from various other online sources such as the [World Health Organisation](https://apps.who.int/gho/data/node.main.A1367?lang=en) and [Institute of Health Metrics and Evaluation (IHME), Global Burden of Disease (GBD)](http://ghdx.healthdata.org/gbd-results-tool).
#
# ## Dataset limitations
#
# - The current limitations of this dataset (and this current analyses) are related to the data sources. Since the original data dictionary and original raw data sources was unable to be determined, we had to make assumptions on the representation of the values in the dataset.
#
# ## Assumptions in current analyses
#
# - Assumptions in this current analysis
#   - Deaths are attributed to malaria,
#
#   - The 'Code' variable in the datasets represent the [3 letter ISO 3166-1 alpha-3 country code](https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3),
#
#   - SDI refers to ['Socio-demographic Index'](http://ghdx.healthdata.org/record/ihme-data/gbd-2015-socio-demographic-index-sdi-1980%E2%80%932015), which is a summary measure of a geography's socio-demographic development. It is based on average income per person, educational attainment, and total fertility rate (TFR).
#
#   - [Malaria incidence rate (per 1 000 population at risk)](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/4670): refers to the number of malaria cases per 1000 population at risk per year. Population at risk is defined as population living in arease where malaria transmission occurs.
#
#
#
#   - The composite variables/metrics in the current datasets, `'Deaths - Malaria - Sex: Both - Age: Age-standardized (Rate) (per 100,000 people)'` and `'Incidence of malaria (per 1,000 population at risk) (per 1,000 population at risk)'`, were calculated with minimal error and are an accurate representation of the age-standardised malaria death rate (per 100,000 people) and malaria incidence (per 1,000 people) per year respectively.
#
#   - The baseline population estimates used for the calculation of composite metrics `'Deaths - Malaria - Sex: Both - Age: Age-standardized (Rate) (per 100,000 people)'` and `'Incidence of malaria (per 1,000 population at risk) (per 1,000 population at risk)'` were based on the same population estimates for that particular entity/country for that particular year
#
#
# ## Limitations of current analyses
#
# - An important limitation of the current analyses is that the original data sources were not able to be cross-validated.
#
# - Any preprocessing steps done prior to the 3 datasets retrieved from the [Github repo](https://github.com/rfordatascience/tidytuesday/tree/master/data/2018/2018-11-13) are also not known.
#
# - The definitions of malaria, case incidence of malaria and deaths attributable to malaria is also not known.
#
# - More importantly, the exact calculation of the composite metrics `'Deaths - Malaria - Sex: Both - Age: Age-standardized (Rate) (per 100,000 people)'` and `'Incidence of malaria (per 1,000 population at risk) (per 1,000 population at risk)'` is not known, and therefore it would be difficult to estimate or quantify the errors contained within this analysis.
#
# In light of the limitations of the current analyses, statistical testing in this current analyses might lead to erroneous conclusions. This would be due to the lack of validation of the original data sources as well as the lack of understanding on how the composite metrics were determined. Statistical testing would therefore not be conducted for this current analyses.
#
#
# # Prior data preprocessing steps:
#
# ## **malaria_deaths.csv -> malaria_processed_deaths.csv: `deaths`**
#
# - Tidy up column names:
#   - lowercased all column names
#   - renamed column name for `'Deaths - Malaria - Sex: Both - Age: Age-standardized (Rate) (per 100,000 people)'` to `'age_std_death_rate'`
#
# - Imputed the missing `'Code'` values for 'Wales', 'England', 'Scotland', 'Northern Ireland' as 'GBR' as they represent the same geographic region of the United Kingdom
#
# - Added a new column `'entity_type'` to allow subsetting of entity types:
#   - `'Region'` : aggregated geographic regions,
#   - `'SDI`: Socio-demographic Index status
#   - `'Country'`: entities with non-NA `'Code'` values
#   - `'World'`: global aggregate, as indicated by entity value == 'World'
#
# ## **malaria_deaths_age.csv -> malaria_deaths_age_processed.csv: `deaths_age`**
#
# - Dropped the row index column `'Unnamed: 0'` as it does not provide any useful information.
#
# - Imputed the missing `'Code'` values for 'Wales', 'England', 'Scotland', 'Northern Ireland' as 'GBR' as they represent the same geographic region of the United Kingdom
#
# - Added a new column `'entity_type'` to allow subsetting of entity types:
#   - `'Region'` : aggregated geographic regions,
#   - `'SDI`: Socio-demographic Index status
#   - `'Country'`: entities with non-NA `'Code'` values
#   - `'World'`: global aggregate, as indicated by entity value == 'World'
#
# ## **malaria_inc.csv -> malaria_inc_processed.csv: `inc`**
#
# - Tidy up column names:
#   - lowercased all column names
#   - renamed column name for `'Incidence of malaria (per 1,000 population at risk) (per 1,000 population at risk)'` to `'malaria_incidence_1000'`
#
# - Added a new column `'entity_type'` to allow subsetting of entity types:
#   - `'Region'` : aggregated geographic regions,
#   - `'Country'`: entities with non-NA `'Code'` values,
#   - `'World'`: global aggregate, as indicated by entity value == 'World',
#   - `'Income/Demographic`: grouping by income or demographic status. These are entities that contain the following terms:
#     - 'Fragile and conflict affected situations',
#     - 'Heavily indebted poor countries (HIPC)',
#     - 'Late-demographic dividend',
#     - 'Least developed countries: UN classification',
#     - 'Low & middle income',
#     - 'Low income',
#     - 'Lower middle income',
#     - 'Middle income',
#     - 'Pre-demographic dividend',
#     - 'Upper middle income'

# %% [markdown]
# # Load libraries

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.style as style
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns

# %% [markdown]
# # Load preprocessed datasets

# %%
data_folder = Path.cwd().parents[0]/'data/processed'

deaths = pd.read_csv(data_folder/'malaria_deaths_processed.csv')
deaths_age = pd.read_csv(data_folder/'malaria_deaths_age_processed.csv')
inc = pd.read_csv(data_folder/'malaria_inc_processed.csv')

# %% [markdown]
# ## Checking each dataset prior to visualization

# %% [markdown]
# ## malaria_deaths_processed.csv

# %%
deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6156 entries, 0 to 6155
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   entity              6156 non-null   object
#  1   code                5400 non-null   object
#  2   year                6156 non-null   int64
#  3   age_std_death_rate  6156 non-null   float64
#  4   entity_type         6156 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 240.6+ KB

# %%
deaths.entity_type.unique()
# Out:
# array(['Country', 'Region', 'SDI', 'World'], dtype=object)

# %% [markdown]
# ## malaria_deaths_processed.csv

# %%
deaths_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30780 entries, 0 to 30779
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   entity       30780 non-null  object
#  1   code         27000 non-null  object
#  2   year         30780 non-null  int64
#  3   age_group    30780 non-null  object
#  4   deaths       30780 non-null  float64
#  5   entity_type  30780 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
deaths_age.entity_type.unique()
# Out:
# array(['Country', 'Region', 'SDI', 'World'], dtype=object)

# %% [markdown]
# ## malaria_inc_processed.csv

# %%
inc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   entity                  508 non-null    object
#  1   code                    400 non-null    object
#  2   year                    508 non-null    int64
#  3   malaria_incidence_1000  508 non-null    float64
#  4   entity_type             508 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 20.0+ KB

# %%
inc.entity_type.unique()
# Out:
# array(['Country', 'Region', 'Income/Demographic', 'World'], dtype=object)

# %% [markdown]
# # Define functions

# %%
style.use('seaborn-poster') # set the size of the charts
style.use('ggplot') # ggplot style

# %%
def plot_line(
    df, 
    metric,
    hue = None,
    entity_type = None,
    title = None,
    ylabel = None
):
    
    if entity_type is not None:
        entity_type_mask = df.entity_type.isin([entity_type])
        df = df[entity_type_mask]
 
    plt.figure(figsize=(14,10))
    ax = sns.lineplot(
        data = df,
        x = 'year',
        y = metric,
        hue = hue,
        style = hue,
        markers = True,
        dashes = False
    )
    
    ax.set_xlabel('Year', fontsize=14)
    
    if ylabel is None:
        ax.set_ylabel(f'{metric}', fontsize=14)
    else:
        ax.set_ylabel(ylabel, fontsize=14)
    
    if title is None:
        ax.set_title(f"Estimates of {metric}, {df.year.min()} - {df.year.max()}")
    
    else:
        ax.set_title(title, fontsize=18)
    
    # Shrink current axis's height by 10% on the bottom
    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.1,
                     box.width, box.height * 0.9])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    plt.show()

# %%
def plot_age_subplots(
    df, 
    metric,
    title,
    hue = None,
    entity_type = None
):
    unique_age = df.age_group.unique().tolist()
    
    if entity_type is not None:
        
        entity_type_mask = df.entity_type.isin([entity_type])
        df = df[entity_type_mask]
 
    plt.figure(figsize=(16,46))   
    plt.suptitle(title, fontsize=20)
    
    for index, age in enumerate(unique_age):
    
        plt.subplot(5,1,index + 1)
        
        ax = sns.lineplot(
            data = df.loc[df.age_group == age],
            x = 'year',
            y = metric,
            hue = hue,
            markers = True,
            dashes = False,
            style = hue
        )
        ax.set_title(f"Number of deaths by age group: {age}")
        ax.set_xlabel('Year', fontsize=14)
        ax.set_ylabel('Number of deaths', fontsize=14)
        
        # Shrink current axis's height by 10% on the bottom
        box = ax.get_position()
        ax.set_position([box.x0, box.y0 + box.height * 0.1,
                         box.width, box.height * 0.9])

        # Put a legend to the right of the current axis
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.subplots_adjust(left=None, bottom=0.3, right=None, top=None, wspace=None, hspace=0.3)
        
    fig = ax.get_figure()
    fig.tight_layout()
    fig.subplots_adjust(top=0.95)
    
    plt.show()

# %% [markdown]
# # Global trends

# %% [markdown]
# What is the observable global trend of malaria deaths and malaria incidence rates over the years?

# %% [markdown]
# ## Malaria incidence per 1,000 population at risk

# %% [markdown]
# Is there any observable trend for the global estimates of malaria incidence over time?

# %%
plot_line(
    inc, 
    'malaria_incidence_1000',
    entity_type = 'World',
    title = 'Global estimates of malaria incidence (per 1,000 population at risk) from 2000 to 2015',
    ylabel = 'Malaria incidence (per 1,000 population at risk)',
    hue = 'entity'
)

# %%
# get subset of data with entity_type == 'World'
world_inc = inc.loc[(inc.entity_type == 'World'),:]

# subset the maximum value for age_std_death_rate for entity_type == 'World'
world_inc.loc[world_inc.malaria_incidence_1000 == world_inc.malaria_incidence_1000.max(),:]
# Out:
#     entity      code  year  malaria_incidence_1000 entity_type
# 492  World  OWID_WRL  2000              158.124351       World

# %%
# subset the minimum value for age_std_death_rate for entity_type == 'World'
world_inc.loc[world_inc.malaria_incidence_1000 == world_inc.malaria_incidence_1000.min(),:]
# Out:
#     entity      code  year  malaria_incidence_1000 entity_type
# 495  World  OWID_WRL  2015               93.956287       World

# %% [markdown]
# It seems like there is a downward trend of global estimates of malaria incidence (per 1,000 population at risk) from 2000 to 2015. However, it also remains unknown if the decrease in malaria incidence from 158 (per 1,000 population at risk) in 2000 to 94 (per 1,000 population at risk) in 2015 is a meaningful trend.
#
# Note that there are only 4 data points at years 2000, 2005, 2010 and 2015; there are insufficient data points to check for any statistically significant trend at this stage. Furthermore, in view of the limitations of the current analyses (see section `2.5 Limitations of current analyses`, statistical testing in this current analyses might lead to erroneous conclusions. This would be due to the lack of validation of the original data sources as well as the lack of understanding on how the composite metrics were determined.

# %% [markdown]
# ## Age-standardized malaria death rate (per 100,000 people)

# %% [markdown]
# Is there any observable trend for the global estimates of age-standardised malaria death rate over time?

# %%
plot_line(
    deaths, 
    'age_std_death_rate',
    entity_type = 'World',
    title = 'Global estimates of Age-standardized malaria death rate (per 100,000 people) from 1990 to 2016',
    ylabel = 'Age-standardized malaria death rate (per 100,000 people)',
    hue = 'entity'
)

# %%
# get subset of data with entity_type == 'World'
world_deaths = deaths.loc[(deaths.entity_type == 'World'),:]

# subset the maximum value for age_std_death_rate for entity_type == 'World'
world_deaths.loc[world_deaths.age_std_death_rate == world_deaths.age_std_death_rate.max(),:]
# Out:
#      entity      code  year  age_std_death_rate entity_type
# 6061  World  OWID_WRL  2003           15.308365       World

# %% [markdown]
# It seems like there was an uptrend in the age-standardised malaria death rate per 100,000 people till 2003, and then there was a reversal of the trend to a downtrend from 2003 onwards. To understand this trend better, we would need to combine other sources of information - such as Malaria intervention and prevention programs and initiatives implemented by organisations such as the [World Health Organisation](https://www.who.int/teams/global-malaria-programme) as well as the [Bill and Melinda Gates Foundation](https://www.gatesfoundation.org/our-work/programs/global-health/malaria) during this particular time period.

# %% [markdown]
# ## Number of malaria deaths by age group

# %% [markdown]
# Is there any observable trend for the global estimates of number of malaria deaths by age group over time?

# %%
plot_line(
    deaths_age, 
    'deaths',
    hue = 'age_group',
    entity_type = 'World',
    title = 'Global estimates of number of malaria deaths by age group, from 1990 to 2016',
    ylabel = 'Number of deaths'
)

# %% [markdown]
# Most of the malaria deaths from global estimates are from the 'Under 5' age group. Similar to the plot above for `Global estimates of Age-standardized malaria death rate (per 100,000 people) from 1990 to 2016`, it seems like there was an gradual uptrend till 2003; then there was a reversal of trend to a gradual downward trend from 2003 onwards.
#
# However, the global estimates on the number of deaths still remain high at more than 500,000 malaria deaths/year for children Under 5 years old.
#
# Let's examine the total global estimates of number of deaths by age group for the entire time period below:

# %%
# group dataset by age_group, 
# sum the total number of deaths for each age_group and 
# rename the column name to 'total_deaths'. Then reset row index to allow for plotting

deaths_age_grp = deaths_age.\
    groupby('age_group').\
    deaths.\
    sum().\
    rename('total_deaths').\
    reset_index()

deaths_age_grp
# Out:
#      age_group  total_deaths
# 0        15-49  8.462569e+06
# 1         5-14  1.026816e+07
# 2        50-69  4.840002e+06
# 3  70 or older  3.003205e+06
# 4      Under 5  8.726745e+07

# %%
plt.figure(figsize=(8,6))
plt.title('Global estimates of total number of deaths by age group, \n 1990 to 2016')

ax = sns.barplot(
    data = deaths_age_grp,
    x = 'total_deaths',
    y = 'age_group'
)
plt.ylabel('Age groups')
plt.xlabel('Total number of malaria deaths in millions')
ax.xaxis.set_major_formatter(ticker.EngFormatter())

# %% [markdown]
# There is a disproportionate number of malaria deaths in children younger than 5 years old. Let's examine the dataset by regions.

# %% [markdown]
# # Regional trends

# %% [markdown]
# Is there any observable regional trend of malaria deaths and malaria incidence rates over the years?

# %% [markdown]
# ## Malaria incidence per 1,000 population at risk

# %% [markdown]
# Is there any observable trend for malaria incidence by regions?

# %%
plot_line(
    inc, 
    'malaria_incidence_1000',
    entity_type = 'Region',
    title = 'Regional estimates of malaria incidence (per 1,000 population at risk) from 2000 to 2015',
    ylabel = 'Malaria incidence (per 1,000 population at risk)',
    hue = 'entity'
)

# %% [markdown]
# It seems like there is a general downward trend for malaria incidence in Sub-Saharan Africa. Most of the malaria incidence also seems to occur in Sub-Saharan Africa.
#
# Unfortunately, as there is no access to the data dictionary for the datasets, the representation for the terms `IDA`, `IBRD`, `Early-demographic dividend` are not known.
# - IBRD could refer to the [International Bank for Reconstruction and Development](https://www.worldbank.org/en/who-we-are/ibrd),
# - IDA could refer to the [IDA Foundation](https://www.idafoundation.org/en/who-we-are).
# However, beyond these postulations, it is not known that region or groupings these entities represent.

# %% [markdown]
# ## Age-standardized malaria death rate (per 100,000 people)

# %% [markdown]
# Is there any observable regional trend for the age-standardized malaria death rate over time?

# %%
plot_line(
    deaths, 
    'age_std_death_rate',
    entity_type = 'Region',
    title = 'Regional estimates of Age-standardized malaria death rate (per 100,000 people), \n 1990 to 2016',
    ylabel = 'Age-standardized malaria death rate (per 100,000 people)',
    hue = 'entity'
)

# %% [markdown]
# Observations:
# - There are separate trends for Western Sub-Saharan Africa, Central Sub-Saharan Africa, Sub-Saharan Africa, Eastern Sub-Saharan Africa, and Oceania.
# - Western Sub-Saharan Africa seems to have the highest age-standardized malaria death rate.
# - There seems to be a downward trend in malaria death rate for the African regions from 2003 onwards.
#
# From a quick online search, [Malaria is transmitted in tropical and subtropical areas](https://www.cdc.gov/malaria/about/distribution.html) - these include areas such as Africa South of the Sahara and in parts of Oceania such as Papua New Guinea. However, without understanding the mapping of the countries to the regions used in the current datasets, it would be difficult to draw any comparisions with [existing literature](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3499992) at this stage.
#
# As seen from the earlier global trends in `7.3 Global estimates of number of malaria deaths by age group, from 1990 to 2016`, there was a disproportionate number of deaths in young children under 5 years ago.
#
# Let's explore if these trends differ by age groups and regions:

# %% [markdown]
# ## Number of malaria deaths by age group

# %% [markdown]
# Are there separate trends for the number of malaria deaths by age group for the different regions?

# %%
plot_age_subplots(
    deaths_age, 
    'deaths',
    hue = 'entity',
    entity_type = 'Region',
    title = 'Regional estimates of number of malaria deaths by age group, \n 1990 to 2016'
)

# %%
# Checking the numbers for children Under 5 years old for Western Sub-Saharan Africa:
deaths_age.loc[
    (deaths_age.entity=='Western Sub-Saharan Africa') & (deaths_age.age_group == 'Under 5'), :
]
# Out:
#                           entity code  year age_group         deaths  \
# 6021  Western Sub-Saharan Africa  NaN  1990   Under 5  288512.048844
# 6022  Western Sub-Saharan Africa  NaN  1991   Under 5  300272.011120
# 6023  Western Sub-Saharan Africa  NaN  1992   Under 5  309141.117318
# 6024  Western Sub-Saharan Africa  NaN  1993   Under 5  319898.532911
# 6025  Western Sub-Saharan Africa  NaN  1994   Under 5  328265.746885
# 6026  Western Sub-Saharan Africa  NaN  1995   Under 5  334832.140565
# 6027  Western Sub-Saharan Africa  NaN  1996   Under 5  342488.887970
# 6028  Western Sub-Saharan Africa  NaN  1997   Under 5  346407.509443
# 6029  Western Sub-Saharan Africa  NaN  1998   Under 5  357661.103732
# 6030  Western Sub-Saharan Africa  NaN  1999   Under 5  367879.583172
# 6031  Western Sub-Saharan Africa  NaN  2000   Under 5  375540.644610
# 6032  Western Sub-Saharan Africa  NaN  2001   Under 5  389360.493929
# 6033  Western Sub-Saharan Africa  NaN  2002   Under 5  401679.231857
# 6034  Western Sub-Saharan Africa  NaN  2003   Under 5  420910.173248
# 6035  Western Sub-Saharan Africa  NaN  2004   Under 5  427535.066957
# 6036  Western Sub-Saharan Africa  NaN  2005   Under 5  431491.934987
# 6037  Western Sub-Saharan Africa  NaN  2006   Under 5  444771.033066
# 6038  Western Sub-Saharan Africa  NaN  2007   Under 5  451638.519169
# 6039  Western Sub-Saharan Africa  NaN  2008   Under 5  462236.035769
# 6040  Western Sub-Saharan Africa  NaN  2009   Under 5  442810.426399
# 6041  Western Sub-Saharan Africa  NaN  2010   Under 5  424920.723765
# 6042  Western Sub-Saharan Africa  NaN  2011   Under 5  408245.335310
# 6043  Western Sub-Saharan Africa  NaN  2012   Under 5  387718.867187
# 6044  Western Sub-Saharan Africa  NaN  2013   Under 5  378687.739082
# 6045  Western Sub-Saharan Africa  NaN  2014   Under 5  367080.869969
# 6046  Western Sub-Saharan Africa  NaN  2015   Under 5  354366.297704
# 6047  Western Sub-Saharan Africa  NaN  2016   Under 5  353171.602621
#
#      entity_type
# 6021      Region
# 6022      Region
# 6023      Region
# 6024      Region
# 6025      Region
# 6026      Region
# 6027      Region
# 6028      Region
# 6029      Region
# 6030      Region
# 6031      Region
# 6032      Region
# 6033      Region
# 6034      Region
# 6035      Region
# 6036      Region
# 6037      Region
# 6038      Region
# 6039      Region
# 6040      Region
# 6041      Region
# 6042      Region
# 6043      Region
# 6044      Region
# 6045      Region
# 6046      Region
# 6047      Region

# %% [markdown]
# Observations across the different subplots:
# - most deaths are reported in African regions across all age groups, especially Sub-Saharan Africa,
# - the trend for Sub-Saharan Africa and Western Sub-Saharan Africa seem to be similar.
# - for Sub-Saharan Africa and the subset Western Sub-Saharan Africa:
#   - it seems like there is a gradual observable uptrend for the number of deaths across all age groups from 1990 till the period of 2003-2005,
#   - and then there seems to be a slight downtrend for children and teenagers up till 14 from 2003-2005 onwards, and stabilisation of the numbers for the adults and teenagers aged 15 and above.
#   - however, the number of deaths in children younger than 5 years old in 2016 (353171) remain higher than the reported numbers in the same region in 1990 (288512).
#
# So, although there is a global downtrend in the Age-standardized malaria death rate (per 100,000 people) from 2003 onwards (section 7.2), the number of malaria deaths in Africa still remain very high, especially in children under 5 years old in Sub-Saharan Africa.
# - It is possible that these observable differences could likely be due to population growth in these regions during that time period. However, without population data, it is not possible to confirm such postulations.
#
# Let's examine if the trends differ by income/demographic groupings:

# %% [markdown]
# # Trends by income/demographic groups

# %% [markdown]
# What is the trend by income/demographic groupings over the years?

# %% [markdown]
# ## Malaria incidence per 1,000 population at risk

# %% [markdown]
# Is there any observable trend for malaria incidence by income/demographic groupings?

# %%
plot_line(
    inc, 
    'malaria_incidence_1000',
    entity_type = 'Income/Demographic',
    title = 'Estimates of malaria incidence (per 1,000 population at risk) \
    \n by income/demographic groups \n 2000 to 2015',
    ylabel = 'Malaria incidence (per 1,000 population at risk)',
    hue = 'entity'
)

# %% [markdown]
# [Demographic dividend](https://en.wikipedia.org/wiki/Demographic_dividend) is a technical term that is defined by the United Nations Population Fund.
#
# However, in view of the lack of understanding of the categorisation of countries into the various income and demographic groups for this dataset, it is difficult to comment on the downward trend exhibited by the 'Pre-demographic dividend' entity.

# %% [markdown]
# ## Age-standardized malaria death rate (per 100,000 people)

# %% [markdown]
# Is there any observable trend for age-standardized malaria death rate by income/demographic groupings?

# %%
plot_line(
    deaths, 
    'age_std_death_rate',
    entity_type = 'SDI',
    title = 'Estimates of Age-standardized malaria death rate (per 100,000 people)\
    \n by Socio-demographic Index, \n 1990 to 2016',
    ylabel = 'Age-standardized malaria death rate (per 100,000 people)',
    hue = 'entity'
)

# %% [markdown]
# ## Number of malaria deaths by age group

# %% [markdown]
# Is there any observable trend for estimates of the number of malaria deaths by income/demographic groupings?

# %%
plot_age_subplots(
    deaths_age, 
    'deaths',
    hue = 'entity',
    entity_type = 'SDI',
    title = 'Estimates of the number of malaria deaths by age group \
    \n and Socio-demographic Index, \n 1990 to 2016'
)

# %% [markdown]
# The high number of malaria deaths are mainly in low and low-middle Socio-Demographic Index countries.
# Unfortunately, without uderstanding the mapping of the countries to the regions and groupings, it is difficult to explore these possible relationships further.

# %% [markdown]
# # What are the countries with the high numbers of malaria deaths?

# %%
# subset countries with > 100 age_std_death_rate
deaths_rate_100 = deaths.loc[(deaths.age_std_death_rate > 100) & (deaths.entity_type == 'Country'), :]
deaths_rate_100.entity.unique()
# Out:
# array(['Benin', 'Burkina Faso', 'Burundi', 'Cameroon',
#        'Central African Republic', "Cote d'Ivoire",
#        'Democratic Republic of Congo', 'Equatorial Guinea', 'Ghana',
#        'Guinea', 'Liberia', 'Malawi', 'Mali', 'Mozambique', 'Niger',
#        'Nigeria', 'Sierra Leone', 'Togo', 'Uganda'], dtype=object)

# %%
plot_line(
    deaths_rate_100, 
    'age_std_death_rate',
    entity_type = 'Country',
    title = 'Estimates of Age-standardized malaria death rate (per 100,000 people) > 100\
    \n 1990 to 2016',
    ylabel = 'Age-standardized malaria death rate (per 100,000 people)',
    hue = 'entity'
)

# %% [markdown]
# There are too many countries to visualize. Try subsetting by absolute numbers instead:

# %%
# subset countries with > 50000 deaths
deaths_50000 = deaths_age.loc[(deaths_age.deaths > 50000) & (deaths_age.entity_type == 'Country'), :]
deaths_50000.entity.unique()
# Out:
# array(['Democratic Republic of Congo', 'Nigeria', 'Uganda'], dtype=object)

# %%
deaths_50000
# Out:
#                             entity code  year age_group         deaths  \
# 1458  Democratic Republic of Congo  COD  1990   Under 5   63737.689219
# 1459  Democratic Republic of Congo  COD  1991   Under 5   66188.445300
# 1460  Democratic Republic of Congo  COD  1992   Under 5   67660.347067
# 1461  Democratic Republic of Congo  COD  1993   Under 5   69705.791513
# 1462  Democratic Republic of Congo  COD  1994   Under 5   71423.732469
# 1463  Democratic Republic of Congo  COD  1995   Under 5   74631.466991
# 1464  Democratic Republic of Congo  COD  1996   Under 5   76708.241562
# 1465  Democratic Republic of Congo  COD  1997   Under 5   79370.617502
# 1466  Democratic Republic of Congo  COD  1998   Under 5   82044.121257
# 1467  Democratic Republic of Congo  COD  1999   Under 5   83330.706594
# 1468  Democratic Republic of Congo  COD  2000   Under 5   83723.303092
# 1469  Democratic Republic of Congo  COD  2001   Under 5   86331.656349
# 1470  Democratic Republic of Congo  COD  2002   Under 5   86669.015047
# 1471  Democratic Republic of Congo  COD  2003   Under 5   89031.511127
# 1472  Democratic Republic of Congo  COD  2004   Under 5   88144.692285
# 1473  Democratic Republic of Congo  COD  2005   Under 5   88988.048069
# 1474  Democratic Republic of Congo  COD  2006   Under 5   91328.906352
# 1475  Democratic Republic of Congo  COD  2007   Under 5   92117.735098
# 1476  Democratic Republic of Congo  COD  2008   Under 5   91994.243464
# 1477  Democratic Republic of Congo  COD  2009   Under 5   89522.161359
# 1478  Democratic Republic of Congo  COD  2010   Under 5   85680.544767
# 1479  Democratic Republic of Congo  COD  2011   Under 5   80483.363357
# 1480  Democratic Republic of Congo  COD  2012   Under 5   72545.248012
# 1481  Democratic Republic of Congo  COD  2013   Under 5   66999.935285
# 1482  Democratic Republic of Congo  COD  2014   Under 5   63676.761582
# 1483  Democratic Republic of Congo  COD  2015   Under 5   58237.543574
# 1484  Democratic Republic of Congo  COD  2016   Under 5   57948.800436
# 3888                       Nigeria  NGA  1990   Under 5  169612.233561
# 3889                       Nigeria  NGA  1991   Under 5  177084.049314
# 3890                       Nigeria  NGA  1992   Under 5  182532.593757
# 3891                       Nigeria  NGA  1993   Under 5  189569.206430
# 3892                       Nigeria  NGA  1994   Under 5  194656.088044
# 3893                       Nigeria  NGA  1995   Under 5  197338.650744
# 3894                       Nigeria  NGA  1996   Under 5  201157.356812
# 3895                       Nigeria  NGA  1997   Under 5  203241.331724
# 3896                       Nigeria  NGA  1998   Under 5  209637.811573
# 3897                       Nigeria  NGA  1999   Under 5  213589.926372
# 3898                       Nigeria  NGA  2000   Under 5  214670.435525
# 3899                       Nigeria  NGA  2001   Under 5  220029.444440
# 3900                       Nigeria  NGA  2002   Under 5  221336.434630
# 3901                       Nigeria  NGA  2003   Under 5  229889.595356
# 3902                       Nigeria  NGA  2004   Under 5  228447.146764
# 3903                       Nigeria  NGA  2005   Under 5  228083.474121
# 3904                       Nigeria  NGA  2006   Under 5  243617.397958
# 3905                       Nigeria  NGA  2007   Under 5  251055.865873
# 3906                       Nigeria  NGA  2008   Under 5  261794.558211
# 3907                       Nigeria  NGA  2009   Under 5  247613.226354
# 3908                       Nigeria  NGA  2010   Under 5  234210.657628
# 3909                       Nigeria  NGA  2011   Under 5  222363.642017
# 3910                       Nigeria  NGA  2012   Under 5  211394.361880
# 3911                       Nigeria  NGA  2013   Under 5  209137.882601
# 3912                       Nigeria  NGA  2014   Under 5  204311.729911
# 3913                       Nigeria  NGA  2015   Under 5  194839.592274
# 3914                       Nigeria  NGA  2016   Under 5  193263.307196
# 5684                        Uganda  UGA  2004   Under 5   50800.983895
#
#      entity_type
# 1458     Country
# 1459     Country
# 1460     Country
# 1461     Country
# 1462     Country
# 1463     Country
# 1464     Country
# 1465     Country
# 1466     Country
# 1467     Country
# 1468     Country
# 1469     Country
# 1470     Country
# 1471     Country
# 1472     Country
# 1473     Country
# 1474     Country
# 1475     Country
# 1476     Country
# 1477     Country
# 1478     Country
# 1479     Country
# 1480     Country
# 1481     Country
# 1482     Country
# 1483     Country
# 1484     Country
# 3888     Country
# 3889     Country
# 3890     Country
# 3891     Country
# 3892     Country
# 3893     Country
# 3894     Country
# 3895     Country
# 3896     Country
# 3897     Country
# 3898     Country
# 3899     Country
# 3900     Country
# 3901     Country
# 3902     Country
# 3903     Country
# 3904     Country
# 3905     Country
# 3906     Country
# 3907     Country
# 3908     Country
# 3909     Country
# 3910     Country
# 3911     Country
# 3912     Country
# 3913     Country
# 3914     Country
# 5684     Country

# %%
deaths_50000.age_group.value_counts()
# Out:
# Under 5    55
# Name: age_group, dtype: int64

# %%
plot_line(
    deaths_50000, 
    'deaths',
    hue = 'entity',
    title = 'Estimates of the number of malaria deaths > 50,000\
     \n 1990 to 2016'
)

# %% [markdown]
# Unfortunately it seems like a disproportionate number of malaria deaths occur in Nigeria and the Demographic Republic of Congo. All of these deaths are in children under 5 years old.
# Addressing malaria and the provision of healthcare in these countries are [multi-faceted](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7026512) and [challenging](https://malariajournal.biomedcentral.com/articles/10.1186/s12936-015-1024-5), and require further country-specific analyses to understand the issue in further detail.

# %% [markdown]
# # Considerations to improve the current analyses
#
#
#
# - **Understanding what was the extent to which the observed trends in malaria incidence and malaria deaths over time could be attributed to better reporting and better malaria diagnosis methods.**
#
#   - From the visualizations of the regional trends and visualizations by income/demographic groups, a disproportionate number of deaths and malaria incidence occur in Africa or in poor/low income countries.
#   - The healthcare resources available in these countries are not known, but is likely to be limited.
#   - From [previous literature](https://www.thelancet.com/journals/lancet/article/PIIS0140-6736(18)30324-6/fulltext), the gold standard for malaria diagnosis involves microscopy analyses of stained blood films. However, rapid diagnostic kits are used for first-line investigation.
#   - These [rapid diganostic kits emerged in the early 1990s](https://malariajournal.biomedcentral.com/articles/10.1186/s12936-019-3028-z) but had variable field performance.
#   - The [WHO malaria rapid diagnostic test product testing programme only started in 2008](https://malariajournal.biomedcentral.com/articles/10.1186/s12936-019-3028-z) to evaluate the performance of such rapid diagnostic kits.
#   - Some papers have postulated that the [observed increase in malaria cases are associated with improved diagnostic availability rather than a resurgence of malaria in those areas.](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6658057).
#   - In this current analyses, just purely visualizing the trends of malaria incidence and malaria deaths over time without additional information on how the information and composite metrics were derived could result in erroneous conclusions.
#   - Therefore, understanding and quantifying the extent to which the observed trends in malaria incidence and malaria deaths over time could be attributed to better reporting and better malaria diagnosis methods would be able to improve the current analyses.
#
#
#
# - **Determining if the observed trends were statistically significant would reduce the risk of erroneous inferences from the observed trends.**
#   - In this current analyses, the exact calculation of the composite metrics `'Deaths - Malaria - Sex: Both - Age: Age-standardized (Rate) (per 100,000 people)'` and `'Incidence of malaria (per 1,000 population at risk) (per 1,000 population at risk)'` was not known
#   - There was also a lack of validation of the original data sources
#   - It is likely that the [malaria incidence numbers](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/4670) and [malaria death rates](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/16) in the 3 datasets (of which this analysis was based on) were already adjusted estimates instead of actual reported numbers.
#   - Statistical testing was therefore not conducted to reduce the risk of any erroneous conclusions.
#   - Only visualizations were done, and observable trends were commented on.
#
#
#
# - **If the [malaria incidence numbers](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/4670) and [malaria death rates](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/16) in the 3 datasets (of which this analysis was based on) were indeed point estimates instead of actual reported numbers, the visualizations would be improved if the line charts also contained the 95% confidence intervals, to quantify the level of uncertainty in the visualized trends**.
#
#
#
# - **If the mappings of the categories to the aggregate groups are known (for example, the exact countries included in countries categorized as 'Low SDI'), then we can also visualize percentage contributions of each country in the time series charts.**
#
#
#
# - **The current analyses can be improved by improving the utility of the problem statement to answer specific questions that have social/economic/policy-related implications. Further data can then be gathered and analyses conducted to address the problem statement.**
#
#
#
#   - Possible questions could be:
#     - Did the implementation of a particular malaria prevention program in a particular region/country have any impact on the malaria incidence or number of malaria deaths in that particular region for that particular time period?
#     - Did the provision of insecticide-treated mosquito nets, indoor residual spraying and other vector control measures for a particular region at a particular point in time have any impact on the malaria incidence on that region for that time period?
